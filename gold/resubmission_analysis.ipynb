# %%
# %sql

select * from rwd.silver.primary_cancer_condition;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Patient_ID</th><th>Primary_Cancer_Condition</th><th>Diagnosis_Date</th><th>Hospital</th></tr></thead><tbody><tr><td>P005</td><td>Hepatocellular Carcinoma</td><td>2024-07-14</td><td>Narayana Health</td></tr><tr><td>P008</td><td>Pancreatic Cancer</td><td>2024-03-18</td><td>Manipal Hospitals</td></tr><tr><td>P001</td><td>Breast Carcinoma</td><td>2024-08-12</td><td>Apollo Hospitals</td></tr><tr><td>P009</td><td>Gastric Cancer</td><td>2024-04-10</td><td>Sankara Nethralaya</td></tr><tr><td>P003</td><td>Colorectal Cancer</td><td>2024-05-19</td><td>Fortis Chennai</td></tr><tr><td>P002</td><td>Lung Adenocarcinoma</td><td>2023-11-03</td><td>AIIMS Delhi</td></tr><tr><td>P006</td><td>Ovarian Cancer</td><td>2023-12-01</td><td>Max Healthcare</td></tr><tr><td>P010</td><td>Bladder Cancer</td><td>2023-10-05</td><td>Tata Memorial</td></tr><tr><td>P004</td><td>Prostate Cancer</td><td>2023-09-25</td><td>CMC Vellore</td></tr><tr><td>P007</td><td>Melanoma</td><td>2024-06-22</td><td>KIMS Hyderabad</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import *
from pyspark.sql.window import Window

# %%
df = spark.read.table("rwd.silver.primary_cancer_condition")

# %%
w = (
    Window
        .partitionBy("patient_id")
        .orderBy("Diagnosis_Date")
)

df_with_prev = (
    df.withColumn("previous_diagnosis", lag("Diagnosis_Date").over(w))
      .withColumn(
          "days_since_last_visit",
          datediff("Diagnosis_Date", "previous_diagnosis")
      )
      .withColumn(
          "is_readmission_30d",
          when(col("days_since_last_visit") <= 30, 1).otherwise(0)
      )
)

# %%
display(df_with_prev)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Patient_ID</th><th>Primary_Cancer_Condition</th><th>Diagnosis_Date</th><th>Hospital</th><th>previous_diagnosis</th><th>days_since_last_visit</th><th>is_readmission_30d</th></tr></thead><tbody><tr><td>P001</td><td>Breast Carcinoma</td><td>2024-08-12</td><td>Apollo Hospitals</td><td>null</td><td>null</td><td>0</td></tr><tr><td>P002</td><td>Lung Adenocarcinoma</td><td>2023-11-03</td><td>AIIMS Delhi</td><td>null</td><td>null</td><td>0</td></tr><tr><td>P003</td><td>Colorectal Cancer</td><td>2024-05-19</td><td>Fortis Chennai</td><td>null</td><td>null</td><td>0</td></tr><tr><td>P004</td><td>Prostate Cancer</td><td>2023-09-25</td><td>CMC Vellore</td><td>null</td><td>null</td><td>0</td></tr><tr><td>P005</td><td>Hepatocellular Carcinoma</td><td>2024-07-14</td><td>Narayana Health</td><td>null</td><td>null</td><td>0</td></tr><tr><td>P006</td><td>Ovarian Cancer</td><td>2023-12-01</td><td>Max Healthcare</td><td>null</td><td>null</td><td>0</td></tr><tr><td>P007</td><td>Melanoma</td><td>2024-06-22</td><td>KIMS Hyderabad</td><td>null</td><td>null</td><td>0</td></tr><tr><td>P008</td><td>Pancreatic Cancer</td><td>2024-03-18</td><td>Manipal Hospitals</td><td>null</td><td>null</td><td>0</td></tr><tr><td>P009</td><td>Gastric Cancer</td><td>2024-04-10</td><td>Sankara Nethralaya</td><td>null</td><td>null</td><td>0</td></tr><tr><td>P010</td><td>Bladder Cancer</td><td>2023-10-05</td><td>Tata Memorial</td><td>null</td><td>null</td><td>0</td></tr></tbody></table></div>
